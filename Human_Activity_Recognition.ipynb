# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Importing the data

# %%
train = pd.read_csv("train.csv")
test=pd.read_csv("test.csv")

# %%
train.head()
# Out:
#    tBodyAcc-mean()-X  tBodyAcc-mean()-Y  tBodyAcc-mean()-Z  tBodyAcc-std()-X  \
# 0           0.288585          -0.020294          -0.132905         -0.995279
# 1           0.278419          -0.016411          -0.123520         -0.998245
# 2           0.279653          -0.019467          -0.113462         -0.995380
# 3           0.279174          -0.026201          -0.123283         -0.996091
# 4           0.276629          -0.016570          -0.115362         -0.998139
#
#    tBodyAcc-std()-Y  tBodyAcc-std()-Z  tBodyAcc-mad()-X  tBodyAcc-mad()-Y  \
# 0         -0.983111         -0.913526         -0.995112         -0.983185
# 1         -0.975300         -0.960322         -0.998807         -0.974914
# 2         -0.967187         -0.978944         -0.996520         -0.963668
# 3         -0.983403         -0.990675         -0.997099         -0.982750
# 4         -0.980817         -0.990482         -0.998321         -0.979672
#
# ...

# %%
test.head()
# Out:
#    tBodyAcc-mean()-X  tBodyAcc-mean()-Y  tBodyAcc-mean()-Z  tBodyAcc-std()-X  \
# 0           0.257178          -0.023285          -0.014654         -0.938404
# 1           0.286027          -0.013163          -0.119083         -0.975415
# 2           0.275485          -0.026050          -0.118152         -0.993819
# 3           0.270298          -0.032614          -0.117520         -0.994743
# 4           0.274833          -0.027848          -0.129527         -0.993852
#
#    tBodyAcc-std()-Y  tBodyAcc-std()-Z  tBodyAcc-mad()-X  tBodyAcc-mad()-Y  \
# 0         -0.920091         -0.667683         -0.952501         -0.925249
# 1         -0.967458         -0.944958         -0.986799         -0.968401
# 2         -0.969926         -0.962748         -0.994403         -0.970735
# 3         -0.973268         -0.967091         -0.995274         -0.974471
# 4         -0.967445         -0.978295         -0.994111         -0.965953
#
# ...

# %%
train['Activity'].unique()
# Out:
# array(['STANDING', 'SITTING', 'LAYING', 'WALKING', 'WALKING_DOWNSTAIRS',
#        'WALKING_UPSTAIRS'], dtype=object)

# %%
train['Activity'].groupby(train['Activity']).count()
# Out:
# Activity
# LAYING                1407
# SITTING               1286
# STANDING              1374
# WALKING               1226
# WALKING_DOWNSTAIRS     986
# WALKING_UPSTAIRS      1073
# Name: Activity, dtype: int64

# %%
test['Activity'].groupby(test['Activity']).count()
# Out:
# Activity
# LAYING                537
# SITTING               491
# STANDING              532
# WALKING               496
# WALKING_DOWNSTAIRS    420
# WALKING_UPSTAIRS      471
# Name: Activity, dtype: int64

# %%
train.describe()
# Out:
#        tBodyAcc-mean()-X  tBodyAcc-mean()-Y  tBodyAcc-mean()-Z  \
# count        7352.000000        7352.000000        7352.000000
# mean            0.274488          -0.017695          -0.109141
# std             0.070261           0.040811           0.056635
# min            -1.000000          -1.000000          -1.000000
# 25%             0.262975          -0.024863          -0.120993
# 50%             0.277193          -0.017219          -0.108676
# 75%             0.288461          -0.010783          -0.097794
# max             1.000000           1.000000           1.000000
#
#        tBodyAcc-std()-X  tBodyAcc-std()-Y  tBodyAcc-std()-Z  tBodyAcc-mad()-X  \
# count       7352.000000       7352.000000       7352.000000       7352.000000
# mean          -0.605438         -0.510938         -0.604754         -0.630512
# std            0.448734          0.502645          0.418687          0.424073
# min           -1.000000         -0.999873         -1.000000         -1.000000
# ...

# %%
test.describe()
# Out:
#        tBodyAcc-mean()-X  tBodyAcc-mean()-Y  tBodyAcc-mean()-Z  \
# count        2947.000000        2947.000000        2947.000000
# mean            0.273996          -0.017863          -0.108386
# std             0.060570           0.025745           0.042747
# min            -0.592004          -0.362884          -0.576184
# 25%             0.262075          -0.024961          -0.121162
# 50%             0.277113          -0.016967          -0.108458
# 75%             0.288097          -0.010143          -0.097123
# max             0.671887           0.246106           0.494114
#
#        tBodyAcc-std()-X  tBodyAcc-std()-Y  tBodyAcc-std()-Z  tBodyAcc-mad()-X  \
# count       2947.000000       2947.000000       2947.000000       2947.000000
# mean          -0.613635         -0.508330         -0.633797         -0.641278
# std            0.412597          0.494269          0.362699          0.385199
# min           -0.999606         -1.000000         -0.998955         -0.999417
# ...

# %% [markdown]
# ### Duplicates

# %%
print("Duplicates in train data :", sum(train.duplicated()))
print("Duplicates in test data :" , sum(test.duplicated()))
# Out:
# Duplicates in train data : 0
# Duplicates in test data : 0

# %% [markdown]
# There are no duplicate columns

# %% [markdown]
# ### Null Values

# %%
print("Null Values in train:", train.isnull().values.sum())
print("Null values in test data: ",test.isnull().values.sum())
# Out:
# Null Values in train: 0
# Null values in test data:  0

# %%
sns.countplot(x='Activity', data=train)
plt.title("Activity data points", fontsize=20)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ### Creating X and Y

# %%
xtrain = train.drop('Activity', axis=1)
ytrain =train.loc[: ,'Activity']

xtest =test.drop('Activity' ,axis=1)
ytest =test.loc[:,'Activity']

# %% [markdown]
# ### Modeling Phase

# %% [markdown]
# #### Naive Bayes Classifier

# %%
from sklearn.naive_bayes import GaussianNB
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix

# %%
model = GaussianNB()

# %%
model.fit(xtrain,ytrain)
# Out:
# GaussianNB()

# %%
pred= model.predict(xtest)
pred[:100]
# Out:
# array(['STANDING', 'STANDING', 'STANDING', 'STANDING', 'STANDING',
#        'STANDING', 'STANDING', 'STANDING', 'SITTING', 'STANDING',
#        'STANDING', 'SITTING', 'SITTING', 'STANDING', 'STANDING',
#        'STANDING', 'SITTING', 'SITTING', 'STANDING', 'STANDING',
#        'STANDING', 'STANDING', 'STANDING', 'STANDING', 'STANDING',
#        'STANDING', 'STANDING', 'STANDING', 'STANDING', 'SITTING',
#        'SITTING', 'SITTING', 'SITTING', 'SITTING', 'STANDING', 'STANDING',
#        'STANDING', 'STANDING', 'STANDING', 'SITTING', 'SITTING',
#        'SITTING', 'STANDING', 'STANDING', 'SITTING', 'SITTING',
#        'STANDING', 'SITTING', 'STANDING', 'STANDING', 'STANDING',
#        'STANDING', 'STANDING', 'SITTING', 'STANDING', 'LAYING', 'LAYING',
#        'LAYING', 'LAYING', 'LAYING', 'LAYING', 'LAYING', 'LAYING',
#        'LAYING', 'LAYING', 'LAYING', 'LAYING', 'LAYING', 'LAYING',
#        'LAYING', 'LAYING', 'LAYING', 'LAYING', 'LAYING', 'LAYING',
# ...

# %% [markdown]
# ### Confusion Matrix

# %%
plt.figure(figsize=(6,6))
cm = confusion_matrix(pred, ytest)

sns.heatmap(cm, square=True , annot=True ,fmt='d')
plt.xlabel('True Values')
plt.ylabel('Predicted Values')
plt.plot()
# Out:
# []

# %%
from sklearn import metrics
print(metrics.classification_report(pred, ytest, labels=list(train['Activity'].unique())))
# Out:
#                     precision    recall  f1-score   support
#
#           STANDING       0.87      0.79      0.83       587
#            SITTING       0.73      0.58      0.65       610
#             LAYING       0.61      0.96      0.75       338
#            WALKING       0.84      0.82      0.83       505
# WALKING_DOWNSTAIRS       0.61      0.83      0.70       310
#   WALKING_UPSTAIRS       0.96      0.76      0.84       597
#
#           accuracy                           0.77      2947
#          macro avg       0.77      0.79      0.77      2947
#       weighted avg       0.80      0.77      0.77      2947

# %% [markdown]
# ### Accuracy

# %%
from sklearn.metrics import accuracy_score
print("Accuracy of the model:" , accuracy_score(ytest,pred))
# Out:
# Accuracy of the model: 0.7702748557855447
